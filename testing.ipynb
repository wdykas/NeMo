# %%
# Test Fastpitch checkpoints trained on OpenSLR > German Neutral TTS Dataset with pre-trained hifigan vocoder

# %%
# imports
from nemo.collections.tts.models import FastPitchModel
from nemo.collections.tts.models import HifiGanModel
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
import torch
import numpy as np
# Out:
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################
#
# [NeMo W 2022-05-08 01:13:34 experimental:27] Module <class 'nemo.collections.nlp.data.language_modeling.megatron.megatron_batch_samplers.MegatronPretrainingRandomBatchSampler'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1811969/3298542556.py in <module>
#       1 # imports
# ----> 2 from nemo.collections.tts.models import FastPitchModel
#       3 from nemo.collections.tts.models import HifiGanModel
#       4 import IPython.display as ipd
#       5 from matplotlib.pyplot import imshow
#
# /akshita/NeMo/nemo/collections/tts/__init__.py in <module>
#      15 import nemo.collections.tts.data
#      16 import nemo.collections.tts.helpers
# ---> 17 import nemo.collections.tts.models
#
# /akshita/NeMo/nemo/collections/tts/models/__init__.py in <module>
#      22     from nemo.collections.tts.models.fastspeech2_hifigan_e2e import FastSpeech2HifiGanE2EModel
#      23     from nemo.collections.tts.models.glow_tts import GlowTTSModel
# ---> 24     from nemo.collections.tts.models.hifigan import HifiGanModel
#      25     from nemo.collections.tts.models.melgan import MelGanModel
#      26     from nemo.collections.tts.models.mixer_tts import MixerTTSModel
#
# /akshita/NeMo/nemo/collections/tts/models/hifigan.py in <module>
#      26 from nemo.collections.tts.models.base import Vocoder
#      27 from nemo.collections.tts.modules.hifigan_modules import MultiPeriodDiscriminator, MultiScaleDiscriminator
# ---> 28 from nemo.collections.tts.torch.data import VocoderDataset
#      29 from nemo.core.classes import Exportable
#      30 from nemo.core.classes.common import PretrainedModelInfo, typecheck
#
# /akshita/NeMo/nemo/collections/tts/torch/data.py in <module>
#      24 import numpy as np
#      25 import torch
# ---> 26 from nemo_text_processing.text_normalization.normalize import Normalizer
#      27 from tqdm import tqdm
#      28
#
# /akshita/NeMo/nemo_text_processing/text_normalization/normalize.py in <module>
#      35 try:
#      36     from nemo.collections.common.tokenizers.moses_tokenizers import MosesProcessor
# ---> 37     from nemo.collections.nlp.data.text_normalization.utils import post_process_punct
#      38
#      39     NLP_AVAILABLE = True
#
# /akshita/NeMo/nemo/collections/nlp/__init__.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from nemo.collections.nlp import data, losses, models, modules
#      16 from nemo.package_info import __version__
#      17
#
# /akshita/NeMo/nemo/collections/nlp/models/__init__.py in <module>
#      22 from nemo.collections.nlp.models.glue_benchmark.glue_benchmark_model import GLUEModel
#      23 from nemo.collections.nlp.models.information_retrieval import BertDPRModel, BertJointIRModel
# ---> 24 from nemo.collections.nlp.models.intent_slot_classification import (
#      25     IntentSlotClassificationModel,
#      26     MultiLabelIntentSlotClassificationModel,
#
# /akshita/NeMo/nemo/collections/nlp/models/intent_slot_classification/__init__.py in <module>
#      16     IntentSlotClassificationModel,
#      17 )
# ---> 18 from nemo.collections.nlp.models.intent_slot_classification.multi_label_intent_slot_classification_model import (
#      19     MultiLabelIntentSlotClassificationModel,
#      20 )
#
# /akshita/NeMo/nemo/collections/nlp/models/intent_slot_classification/multi_label_intent_slot_classification_model.py in <module>
#      37
#      38
# ---> 39 class MultiLabelIntentSlotClassificationModel(IntentSlotClassificationModel):
#      40     def __init__(self, cfg: DictConfig, trainer: Trainer = None):
#      41         """
#
# /akshita/NeMo/nemo/collections/nlp/models/intent_slot_classification/multi_label_intent_slot_classification_model.py in MultiLabelIntentSlotClassificationModel()
#     241         )
#     242
# --> 243     def prediction_probabilities(self, queries: List[str], test_ds: DictConfig) -> npt.NDArray:
#     244         """
#     245         Get prediction probabilities for the queries (intent and slots)
#
# AttributeError: module 'numpy.typing' has no attribute 'NDArray'

# %%
# fastpitch_path="/akshita/r1_to_r2_baseFastpitch_SynMelGen/FastPitch--v_loss=0.6848-epoch=294-last.ckpt"
fastpitch_path="/result/FastPitch/2022-05-07_02-19-19/checkpoints/FastPitch--v_loss=0.6877-epoch=999-last.ckpt"
hfg_ngc="tts_hifigan"
data_path="/Data/openslr-95-german-neutral-tts/thorsten-de/wavs/"
seed=100

# %%
#test
test1 = "Man darf sich nicht von anderen entmutigen lassen."
test1_id = "2edfc39c95ef247c6e39c929d122f4cc"
#val
test2 = "Allergiker sollten einen Staubsauger mit Filter nehmen."
test2_id = "34c7692223011b6153e27ae82ec1a7ae"

# %%
# load models
spec_gen_model = FastPitchModel.load_from_checkpoint(checkpoint_path=fastpitch_path).eval().cuda()
vocoder_model = HifiGanModel.from_pretrained(hfg_ngc, strict=False).eval().cuda()
# Out:
# [NeMo I 2022-05-07 18:37:31 tokenize_and_classify:87] Creating ClassifyFst grammars. This might take some time...
# [NeMo W 2022-05-07 18:37:55 modelPT:148] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /Data/openslr-95-german-neutral-tts/thorsten-de/train_manifest.json
#       sample_rate: 22050
#       sup_data_path: /Data/openslr-95-german-neutral-tts/thorsten-de/sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 132.5526885986328
#       pitch_std: 37.61381912231445
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 0
#
# [NeMo W 2022-05-07 18:37:55 modelPT:155] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /Data/openslr-95-german-neutral-tts/thorsten-de/val_manifest.json
#       sample_rate: 22050
#       sup_data_path: /Data/openslr-95-german-neutral-tts/thorsten-de/sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 132.5526885986328
#       pitch_std: 37.61381912231445
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 0
# [NeMo I 2022-05-07 18:37:55 features:259] PADDING: 1
# [NeMo I 2022-05-07 18:37:55 features:276] STFT using torch
# [NeMo I 2022-05-07 18:37:59 cloud:56] Found existing object /root/.cache/torch/NeMo/NeMo_1.9.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# [NeMo I 2022-05-07 18:37:59 cloud:62] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.9.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo
# [NeMo I 2022-05-07 18:37:59 common:747] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-05-07 18:38:03 modelPT:148] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-05-07 18:38:03 modelPT:155] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-05-07 18:38:03 features:233] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-05-07 18:38:03 features:259] PADDING: 0
# [NeMo I 2022-05-07 18:38:03 features:276] STFT using torch
# [NeMo W 2022-05-07 18:38:03 features:233] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-05-07 18:38:03 features:259] PADDING: 0
# [NeMo I 2022-05-07 18:38:03 features:276] STFT using torch
# [NeMo I 2022-05-07 18:38:05 save_restore_connector:209] Model HifiGanModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.9.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.

# %%
# run inference

with torch.no_grad():
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.enabled = True
    torch.backends.cudnn.benchmark = False
    parsed = spec_gen_model.parse(str_input=test1, normalize=True)
    spectrogram = spec_gen_model.generate_spectrogram(tokens=parsed)
    print(spectrogram.size()) # debug
#     audio = vocoder_model.convert_spectrogram_to_audio(spec=spectrogram, sigma=0.8, denoise=True)
    audio = vocoder_model.convert_spectrogram_to_audio(spec=spectrogram)

spectrogram = spectrogram.to('cpu').numpy()[0]
audio = audio.to('cpu').numpy()[0]
audio = audio / np.abs(audio).max()
# Out:
# torch.Size([1, 80, 262])

# %%
# generated audio
ipd.Audio(audio, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# original audio
ipd.Audio(data_path+test1_id+'.wav', rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline

# visualize the spectrogram

if spectrogram is not None:
    imshow(spectrogram, origin="lower")
    plt.show()

# %%
import matplotlib.pyplot as plt
import librosa

y, sr = librosa.load(data_path+test1_id+'.wav')
spectrogram2 = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=1024, win_length=1024, hop_length=256)

imshow(np.log(spectrogram2)[ :80, :], origin="lower")
plt.show()
